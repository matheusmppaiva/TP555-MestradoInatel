# %% [markdown]
# ##Lista 07 - Exercicio 06

# %% [markdown]
# ###Conjunto de treinamento a ser utilizado:
#
# ![Tabela01.png](data:image/png;base64,...)

# %%
from math import log

# %%
log1_7 = log(1/7,2)
log2_7 = log(2/7,2)

# %% [markdown]
# ###Cálculo da entropia:
#
# H(y) = -[(1/7)log2(1/7) + (2/7)log2(2/7) + (2/7)log2(2/7) + (2/7)log2(2/7)]

# %%
entropia = -((1/7)*log1_7 + 3*((2/7)*log2_7))
print ("Entropia = ", entropia)
# Out:
# Entropia =  1.950212064914747

# %% [markdown]
# ###Separação das classes
# ![Separacao das classes.png](data:image/png;base64,...)

# %% [markdown]
# ###Ganho de informação para cada atributo

# %% [markdown]
# ###Gain(Fever) = 1,95 - [(2/7)*H(Fever=NO) + (3/7)*H(Fever=AVERAGE) + (2/7)*H(Fever=HIGH)]
#
# ###Gain(Vomiting) = 1,95 - [(4/7)*H(Vomiting=NO) + (3/7)*H(Vomiting=YES)]
#
# ###Gain(Shivering) = 1,95 - [(6/7)*H(Shivering=NO) + (1/7)*H(Shivering=YES)]
#
# ###Gain(Diarrhea) = 1,95 - [(3/7)*H(Diarrhea=NO) + (4/7)*H(Diarrhea=YES)]

# %% [markdown]
# ###Gain(Fever) = 1,95 - {(2/7)*[1/2*log2(1/2)+1/2*log2(1/2)] + (3/7)*[1/3*log2(1/3)+1/3*log2(1/3)+1/3*log2(1/3)] + (2/7)*[1/2*log2(1/2)+1/2*log2(1/2)]}
#
# ###Gain(Vomiting) = 1,95 - {(4/7)*[1/4*log2(1/4)+2/4*log2(2/4)+1/4*log2(1/4)] + (3/7)*[1/3*log2(1/3)+2/3*log2(2/3)]}
#
# ###Gain(Shivering) = 1,95 - {(6/7)*[1/6*log2(1/6) + 1/6*log2(1/6) + 2/6*log2(2/6) + 2/6*log2(2/6)]  + (1/7)*[1/1*log2(1/1)]}
#
# ###Gain(Diarrhea) = 1,95 - {(3/7)*[1/3*log2(1/3) + 2/3*log2(2/3)] + (4/7)*[2/4*log2(2/4) + 2/4*log2(2/4)]}

# %%
log1_1 = log(1/1,2)
log1_2 = log(1/2,2)
log1_3 = log(1/3,2)
log1_4 = log(1/4,2)
log1_6 = log(1/6,2)
log2_3 = log(2/3,2)
log2_4 = log(2/4,2)
log2_6 = log(2/6,2)

print (log1_1)
print (log1_2)
print (log1_3)
print (log1_4)
print (log1_6)
print (log2_3)
print (log2_4)
print (log2_6)
# Out:
# 0.0
# -1.0
# -1.5849625007211563
# -2.0
# -2.584962500721156
# -0.5849625007211563
# -1.0
# -1.5849625007211563

# %%
gain_fever = 1.95 - ((2/7)*((1/2)*log1_2 + (1/2)*log1_2) + (3/7)*((1/3)*log1_3 + (1/3)*log1_3 + (1/3)*log1_3) + (2/7)*((1/2)*log1_2 + (1/2)*log1_2))
gain_vomiting = 1.95 - ((4/7)*((1/4)*log1_4 + (2/4)*log2_4 + (1/4)*log1_4) + (3/7)*((1/3)*log1_3 + (2/3)*log2_3))
gain_shivering = 1.95 - ((6/7)*((1/6)*log1_6 + (1/6)*log1_6 + (2/6)*log2_6 + (2/6)*log2_6) + (1/7)*((1/1)*log1_1))
gain_diarrhea = 1.95 - ((3/7)*((1/3)*log1_3 + (2/3)*log2_3) + (4/7)*((2/4)*log2_4 + (2/4)*log2_4))

print("Gain Fever: ", gain_fever)
print("Gain Vomiting: ", gain_vomiting)
print("Gain Shivering: ", gain_shivering)
print("Gain Diarrhea: ", gain_diarrhea)
# Out:
# Gain Fever:  3.200698214594781
# Gain Vomiting:  3.200698214594781
# Gain Shivering:  3.5942535720467053
# Gain Diarrhea:  2.9149839288804955

# %% [markdown]
# ####Será utilizado o atributo "Shivering" como nó raiz da árvore
#
# ###Quando Shivering = YES, independente dos outros atributos, a classe é Influenza

# %% [markdown]
# ![primeiro_no.png](data:image/png;base64,...)

# %% [markdown]
# ![Separacao2.png](data:image/png;base64,...)

# %% [markdown]
# ###Cálculo da nova entropia
#
# H(y) = -[(1/6)log2(1/6) + (1/6)log2(1/6) + (2/6)log2(2/6) + (2/6)log2(2/6)]

# %%
entropia2 = -(2*(1/6)*log1_6 + 2*((2/6)*log2_6))
print ("Entropia = ", entropia2)
# Out:
# Entropia =  1.9182958340544896

# %% [markdown]
# ###Gain(Fever) = 1,9183 - {(2/6)*[1/2*log2(1/2)+1/2*log2(1/2)] + (3/6)*[1/3*log2(1/3)+1/3*log2(1/3)+1/3*log2(1/3)] + (1/6)*[1/2*log2(1/2)]}
#
# ###Gain(Vomiting) = 1,9183 - {(3/6)*[1/3*log2(1/3)+1/3*log2(1/3)+1/3*log2(1/3)] + (3/6)*[1/3*log2(1/3)+2/3*log2(2/3)]}
#
# ###Gain(Diarrhea) = 1,9183 - {(2/6)*[1/2*log2(1/2) + 1/2*log2(1/2)] + (4/6)*[2/4*log2(2/4) + 2/4*log2(2/4)]}

# %%
gain_fever2 = 1.9183 - ((2/6)*((1/2)*log1_2 + (1/2)*log1_2) + (3/6)*((1/3)*log1_3 + (1/3)*log1_3 + (1/3)*log1_3) + (1/6)*((1/2)*log1_2))
gain_vomiting2 = 1.9183 - ((3/6)*((1/3)*log1_3 + (1/3)*log1_3 + (1/3)*log1_3) + (3/6)*((1/3)*log1_3 + (2/3)*log2_3))
gain_diarrhea2 = 1.9183 - ((2/6)*((1/2)*log1_2 + (1/2)*log1_2) + (4/6)*((2/4)*log2_4 + (2/4)*log2_4))

print("New Gain Fever: ", gain_fever2)
print("New Gain Vomiting: ", gain_vomiting2)
print("New Gain Diarrhea: ", gain_diarrhea2)
# Out:
# New Gain Fever:  3.1274479170272445
# New Gain Vomiting:  3.1699291673878225
# New Gain Diarrhea:  2.9183

# %% [markdown]
# ####Será utilizado o atributo "Vomiting" como próximo nó da árvore

# %% [markdown]
# ![segundo_no.png](data:image/png;base64,...)

# %% [markdown]
# ![separacao3.png](data:image/png;base64,...)

# %% [markdown]
# ####Novo calculo de entropia usando Shivering=No e Vomiting=Yes

# %%
entropia3 = -((1/3)*log1_3 + ((2/3)*log2_3))
print ("Entropia = ", entropia3)
# Out:
# Entropia =  0.9182958340544896

# %% [markdown]
# ####Cálculo dos ganhos usando fever e diarrhea

# %%
gain_fever3 = 0.9183 - ((1/3)*((1/1)*log1_1) + (1/3)*((1/1)*log1_1) + (1/3)*((1/1)*log1_1))
gain_diarrhea3 = 0.9183 - ((3/3)*((1/3)*log1_3 + (2/3)*log2_3))

print("New Gain Fever: ", gain_fever3)
print("New Gain Diarrhea: ", gain_diarrhea3)
# Out:
# New Gain Fever:  0.9183
# New Gain Diarrhea:  1.8365958340544895

# %% [markdown]
# ####Será utilizado como novo nó o atributo diarrhea. É percebido que enquanto Shivering=NO e Vomiting=YES, diarrhea será sempre yes, com a classificação dependendo somente do atributo Fever.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Ao verificar o atributo Shivering=NO, Vomiting=NO, é possível verificar que a classificação depende novamente do atributo Diarrhea e em seguida Fever, caso Diarrhea=NO.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Observando a árvore que foi obtida acima, não é possível descartar nenhum atributo da base de treinamento, todos foram necessários para chegar na classificação das doenças.

# %% [markdown]
# ###Utilizando a tabela disponível no nº3 desse exercicio, o classificador não atinge acurácia de 100%, a classificação não está coincidindo com as classes da tabela de validação.
#
# ###Algo que pode ser feito para melhorar a acurácia do classificador é aumentar a quantidade de exemplos de validação. Se por acaso a árvore se sobreajustar, pode ter sua profundidade limitada ou número mínimo de amostras em um nó folha, para evitar o sobreajuste.

# %% [markdown]
# ##Novo conjunto de dados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Cálculo da entropia:
#
# H(y) = -[(1/13)log2(1/13) + (3/13)log2(3/13) + (4/13)log2(4/13) + (5/13)log2(5/13)]

# %%
log1_13 = log(1/13,2)
log3_13 = log(3/13,2)
log4_13 = log(4/13,2)
log5_13 = log(5/13,2)

novaentropia = -((1/13)*log1_13 + (3/13)*log3_13 + (4/13)*log4_13 + (5/13)*log5_13)

print("Novo calculo de entropia: ", novaentropia)
# Out:
# Novo calculo de entropia:  1.8262452584026092

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Gain(Fever) = 1,8262 - [(3/13)*H(Fever=NO) + (5/13)*H(Fever=AVERAGE) + (5/13)*H(Fever=HIGH)]
#
# ###Gain(Vomiting) = 1,8262 - [(8/13)*H(Vomiting=NO) + (5/13)*H(Vomiting=YES)]
#
# ###Gain(Shivering) = 1,8262 - [(7/13)*H(Shivering=NO) + (6/13)*H(Shivering=YES)]
#
# ###Gain(Diarrhea) = 1,8262 - [(5/13)*H(Diarrhea=NO) + (8/13)*H(Diarrhea=YES)]

# %% [markdown]
# ###Gain(Fever) = 1,8262 - {(5/13)*[1/3*log2(1/3)+2/3*log2(2/3)] + (5/13)*[1/5*log2(1/5)+2/5*log2(2/5)+2/5*log2(2/5)] + (5/13)*[2/5*log2(2/5)+2/5*log2(2/5) + 1/5*log2(1/5)]}
#
# ###Gain(Vomiting) = 1,8262 - {(8/13)*[1/8*log2(1/8) + 3/8*log2(3/8) + 2/8*log2(2/8) + 2/8*log2(2/8)] + (5/13)*[2/5*log2(2/5) + 3/5*log2(3/5)]}
#
# ###Gain(Shivering) = 1,8262 - {(7/13)*[1/7*log2(1/7) + 1/7*log2(1/7) + 2/7*log2(2/7) + 3/7*log2(3/7)]  + (6/13)*[2/6*log2(2/6) + 2/6*log2(2/6) + 2/6*log2(2/6)]}
#
# ###Gain(Diarrhea) = 1,8262 - {(5/13)*[1/5*log2(1/5) + 3/5*log2(3/5) + 1/5*log2(1/5)] + (8/13)*[4/8*log2(4/8) + 4/8*log2(4/8)]}

# %%
log1_5 = log(1/5,2)
log2_5 = log(2/5,2)
log1_8 = log(1/8,2)
log3_8 = log(3/8,2)
log3_7 = log(3/7,2)
log3_5 = log(3/5,2)

# %%
gain_fever4 = 1.8262 - ((5/13)*((1/3)*log1_3 + (2_3)*log2_3) + (5/13)*((1/5)*log1_5 + (2/5)*log2_5 + (2/5)*log2_5) + (5/13)*((2/5)*log2_5 + (2/5)*log2_5 + (1/5)*log1_5))
gain_vomiting4 = 1.8262 - ((8/13)*((1/8)*log1_8 + (3/8)*log3_8 +  + (1/4)*log1_4 + (1/4)*log1_4) + (5/13)*((2/5)*log2_5 + (3/5)*log3_5))
gain_shivering4 = 1.8262 - ((7/13)*((1/7)*log1_7 + (1/7)*log1_7 + (2/7)*log2_7 + (3/7)*log3_7) + (6/13)*(3*(1/3)*log1_3))
gain_diarrhea4 = 1.8262 - ((5/13)*((1/5)*log1_5 + (3/5)*log3_5 + (1/5)*log1_5) + (8/13)*((1/2)*log1_2 + (1/2)*log1_2))

print("Gain Fever: ", gain_fever4)
print("Gain Vomiting: ", gain_vomiting4)
print("Gain Shivering: ", gain_shivering4)
print("Gain Diarrhea: ", gain_diarrhea4)
# Out:
# Gain Fever:  8.37478251535963
# Gain Vomiting:  3.3723434977007596
# Gain Shivering:  3.5497670735820535
# Gain Diarrhea:  2.9688733055594883

# %% [markdown]
# ####Será utilizado o atributo Fever como primeiro nó da árvore

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
